# %% [markdown]
# # eno: Hello World
#
# Quick sanity check that everything is set up correctly.

# %%
from pathlib import Path
from datetime import datetime

data_path = Path("~/data/hdd/eno2").expanduser()
data_path.mkdir(exist_ok=True)
test_file = data_path / "hello_world.txt"

test_file.write_text(f"Hello from eno!\nWritten at: {datetime.now().isoformat()}\n")

print(f"Wrote to: {test_file}")
print(f"Contents:\n{test_file.read_text()}")
# Out:
# Wrote to: /home/jovyan/data/hdd/eno2/hello_world.txt
# Contents:
# Hello from eno!
# Written at: 2025-12-06T12:39:41.029077
